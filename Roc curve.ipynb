# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x =  .24,.16,.14,.16,.20,.20
y = .82,.86,.78,.78,.88,.88

# %%
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\Shimanto\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1316: UserWarning: findfont: Font family ['Ricty'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
auc = np.trapz(y,x)
